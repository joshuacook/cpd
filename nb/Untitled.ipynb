# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.io as sio
test = sio.loadmat('../src/project1/mydata.mat')

results = pd.DataFrame(test["mydata"]).T
results.columns = ["x", "y", "theta", "v", "omega", "ready", "theta_dif", "state"]
n = results.shape[0]
results["time"] = np.linspace(1, n*0.033, n)
min_v, max_v = 0, 100
# min_v, max_v = 40,55
fig, ax = plt.subplots(1, 1, figsize=(20,5))
window = results[(results.time > min_v) & (results.time < max_v)]
window.plot(kind="scatter", y="y", x="time", ax=ax, c="cyan", label="y")
window.plot(kind="scatter", y="x", x="time", ax=ax, c="blue", label="x")
window.plot(kind="scatter", y="theta", x="time", ax=ax, c="red", label="theta")
window.plot(kind="scatter", y="omega", x="time", ax=ax, label="omega")
window.plot(kind="scatter", y="theta_dif", x="time", ax=ax, label="theta_dif", c="green")
window.plot(kind="scatter", y="state", x="time", ax=ax, label="state", c="orange")
ax.legend()

# %%
success_records = sio.loadmat('../src/project1/success_records.mat')
success_records = pd.DataFrame(success_records["success_records"]).T
fig, ax = plt.subplots(figsize=(10,10))
success_records[success_records[3] > 2900].plot(kind="scatter", x=2, y=1, c='red', ax=ax)
success_records[~(success_records[3] > 2900)].plot(kind="scatter", x=2, y=1, c="blue", ax=ax)

# %%
window["distance"] = np.sqrt(window.x**2 +  window.y**2)
window
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#              x         y     theta             v         omega  ready  \
# 1309  0.492360 -0.007070 -0.009857  7.984096e-02 -1.176754e-17    0.0
# 1310  0.494994 -0.007096 -0.009857  7.984096e-02 -1.176754e-17    0.0
# 1311  0.497629 -0.007122 -0.009857  7.984096e-02 -1.176754e-17    0.0
# 1312  0.500264 -0.007148 -0.009857  7.984096e-02 -1.176754e-17    0.0
# 1313  0.502898 -0.007174 -0.009857  0.000000e+00  0.000000e+00    0.0
# 1314  0.502898 -0.007174 -0.009857 -2.101847e-17 -3.112136e+00    0.0
# 1315  0.502898 -0.007174 -0.112557  5.819255e-17 -3.016760e+00    0.0
# ...

# %%
results[(results.time > 16.25)].head()
# Out:
#             x         y     theta         v         omega  ready  theta_dif  \
# 467 -0.412064 -0.000374 -0.004973  0.079841 -1.176754e-17    0.0   0.004973
# 468 -0.409429 -0.000387 -0.004973  0.079841 -1.176754e-17    0.0   0.004973
# 469 -0.406794 -0.000401 -0.004973  0.079841 -1.176754e-17    0.0   0.004973
# 470 -0.404160 -0.000414 -0.004973  0.079841 -1.176754e-17    0.0   0.004973
# 471 -0.401525 -0.000427 -0.004973  0.079841 -1.176754e-17    0.0   0.004973
#
#      state       time
# 467    3.0  16.260420
# 468    3.0  16.293098
# 469    3.0  16.325775
# 470    3.0  16.358453
# 471    3.0  16.391130

# %%
fig, ax = plt.subplots(1, 5, figsize=(20,5))
results.plot(kind="scatter", y="x", x="time", ax=ax[0])
results.plot(kind="scatter", y="y", x="time", ax=ax[1])
results.plot(kind="scatter", y="theta", x="time", ax=ax[2])
results.plot(kind="scatter", y="v", x="time", ax=ax[3])
results.plot(kind="scatter", y="omega", x="time", ax=ax[4])

# %%
results.plot(kind="scatter", x="t", y="y")
